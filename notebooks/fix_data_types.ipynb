# %%
import pandas as pd
import pandas as pd
import pandasai as pai
import os
from sqlglot import expressions as exp

os.chdir("..")  # move up one level: notebooks → project root
from src.tools import load_pandas_ai_dataframe
import re
import json

file = pd.read_csv(
    "/home/zcemg08/PycharmProjects/AI_DUBAI_CRYPTO_CLOUD/data/catboost_districts_added_on_v2.csv",
    parse_dates=["added_on", "listing_update_date"]
)

# %%
file["nearest_station1_name"].unique()
# Out:
# array(['Kew Bridge Station', 'Castle Bar Park Station',
#        'Elephant & Castle (Bakerloo) Station', 'Tooting Bec Station',
#        'Angel Station', 'Old Street Station', 'Hillingdon Station',
#        'Arsenal Station', 'Aldgate East Station', 'Shadwell Station',
#        'Royal Victoria Station', 'South Kensington Station',
#        'Berrylands Station', "St. John's Wood Station",
#        'Eden Park Station', 'Harold Wood Station',
#        'Tottenham Court Road Station', 'Barons Court Station',
#        'Brondesbury Park Station', 'Bexley Station',
#        'Pontoon Dock Station', 'Westbourne Park Station',
#        'Preston Road Station', 'Marble Arch Station',
#        'Oxford Circus Station', 'Hounslow East Station',
#        'Hayes & Harlington Station', 'Uxbridge Station',
#        'Southall Station', 'Hackney Downs Station',
#        'Wimbledon Chase Station', 'Elephant & Castle Station',
#        'Waterloo East Station', 'Lloyd Park Tram Stop',
#        'Snaresbrook Station', 'Kilburn High Road Station',
#        'Seven Sisters Station', 'West Ruislip Station',
#        'Nine Elms Station', 'East Finchley Station',
#        'Kew Gardens Station', 'Camden Town Station', 'Marylebone Station',
#        'Acton Main Line Station', 'Mile End Station',
#        'Reedham (Surrey) Station', 'Redbridge Station',
#        'Mudchute Station', "St. James's Park Station",
#        'West Drayton Station', 'Alperton Station',
#        'Crossharbour & London Arena Station', 'Langdon Park Station',
#        'Burnt Oak Station', 'Dollis Hill Station',
#        'Queenstown Road (Battersea) Station', 'Imperial Wharf Station',
#        'Pinner Station', 'Sutton Common Station', 'Belmont Station',
#        'West Kensington Station', 'Elverson Road Station',
#        'Knightsbridge Station', 'Queensbury Station', 'Feltham Station',
#        'Crouch Hill Station', 'Surrey Quays Station',
#        'Great Portland Street Station', 'South Bermondsey Station',
#        'Monument Station', 'Enfield Town Station',
#        'Mitcham Eastfields Station', 'Fulwell Station', 'Hornsey Station',
#        'Hendon Station', 'Essex Road Station', 'Swiss Cottage Station',
#        'Edgware Road (Bakerloo) Station', 'Westferry Station',
#        'Hither Green Station', 'London Bridge Station',
#        'Hampton Wick Station', 'Brent Cross West Station',
#        'Avenue Road Tram Stop', 'Gloucester Road Station',
#        'Selhurst Station', 'Sidcup Station', 'Brentford Station',
#        'Whitechapel Station', 'Kensal Green Station',
#        'Harrow-on-the-Hill Station', 'Kennington Station',
#        'Elmstead Woods Station', 'Blackwall Station',
#        'Headstone Lane Station', 'Hoxton Station',
#        'Willesden Green Station', 'St. Margarets Station',
#        'North Harrow Station', 'Manor House Station', 'Southwark Station',
#        'West Ealing Station', 'Clapham North Station',
#        'Green Park Station',
#        'London Heathrow Airport Terminals 1, 2 & 3 Station',
#        'Ravensbourne Station', 'Plaistow Station', 'Barbican Station',
#        'Tooting Broadway Station', 'Stepney Green Station',
#        'Warwick Avenue Station', 'Tottenham Hale Station',
#        'Drayton Park Station', 'Wimbledon Station', 'Herne Hill Station',
#        'East Acton Station', 'South Quay Station', 'Stanmore Station',
#        'West Dulwich Station', 'Sloane Square Station',
#        'Fulham Broadway Station', 'Finchley Road & Frognal Station',
#        'Canning Town Station', 'Emerson Park Station',
#        'West India Quay Station', 'New Cross Gate Station',
#        'Leicester Square Station', 'Stratford High Street Station',
#        'White City Station', 'Haydons Road Station', 'Ilford Station',
#        'Kentish Town Station', 'Pimlico Station',
#        'Caledonian Road Station', 'Hackney Wick Station',
#        'Harrow & Wealdstone Station', 'Limehouse Station',
#        'Coulsdon South Station', 'Vauxhall Station',
#        'Wandle Park Tram Stop', 'Beckenham Junction Station',
#        'East Dulwich Station', 'Southgate Station',
#        'Chancery Lane Station', 'Bayswater Station',
#        'Brent Cross Station', 'Barking Riverside Station',
#        'Wandsworth Common Station', 'Clapham South Station',
#        'Queens Road Peckham Station', 'Mortlake Station',
#        'Walthamstow Central Station', 'Merton Park Tram Stop',
#        'Charlton Station', 'Dalston Kingsland Station',
#        'Peckham Rye Station', 'Purley Station', 'Wandsworth Road Station',
#        'Northwood Hills Station', 'Woolwich Arsenal Station',
#        'East Putney Station', 'Farringdon Station', 'Bermondsey Station',
#        'Prince Regent Station', 'Earls Court Station',
#        'South Wimbledon Station', 'Putney Station',
#        'Turnham Green Station', 'Wembley Stadium Station',
#        'Baker Street Station', 'Dundonald Road Tram Stop',
#        'Norbury Station', 'Cockfosters Station', "Queen's Park Station",
#        'St. Mary Cray Station', 'Bow Road Station',
#        'King George V Station', 'Canonbury Station',
#        'Hendon Central Station', 'Clapham Junction Station',
#        'Putney Bridge Station', 'Stratford Station',
#        'Hammersmith (District & Piccadilly) Station', 'Lewisham Station',
#        'Ponders End Station', 'Hadley Wood Station',
#        'Canada Water Station', 'Worcester Park Station',
#        'Surbiton Station', 'Piccadilly Circus Station',
#        'Bond Street Station', 'Norbiton Station', 'Hayes Station',
#        'Cambridge Heath Station', 'Kingsbury Station',
#        'Caledonian Road & Barnsbury Station', 'Woolwich Station',
#        'Westcombe Park Station', 'Heron Quays Station',
#        'Chingford Station', 'West Ham Station', 'Wandsworth Town Station',
#        'Stonebridge Park Station', 'Norwood Junction Station',
#        'Woodside Park Station', 'West Norwood Station',
#        'Gidea Park Station', 'Parsons Green Station',
#        'Seven Kings Station', 'Sundridge Park Station', 'Borough Station',
#        'Teddington Station', 'West Silvertown Station',
#        'West Brompton Station', 'Albany Park Station',
#        'Kensington Olympia Station', 'Kilburn Park Station',
#        "Regent's Park Station", 'Romford Station',
#        'Kings Cross Thameslink Station',
#        "Shepherd's Bush (Hammersmith & City) Station",
#        'Bromley South Station', 'East India Station',
#        'Highams Park Station', 'Shoreditch High Street Station',
#        'Rayners Lane Station', 'Mottingham Station',
#        'West Croydon Station', 'Tower Hill Station',
#        'Northolt Park Station', 'Denmark Hill Station',
#        'Stockwell Station', 'Upper Holloway Station', 'Royal Oak Station',
#        'Abbey Wood Station', 'New Southgate Station',
#        'Rectory Road Station', 'Barnes Station',
#        'Battersea Power Underground Station', 'New Malden Station',
#        'Southbury Station', 'Archway Station', 'Acton Town Station',
#        'Beckton Station', 'Forest Hill Station', 'Chalk Farm Station',
#        'Greenwich DLR Station', "King's Cross Station",
#        'Streatham Station', 'Barnehurst Station', 'Golders Green Station',
#        'Hammersmith (Hammersmith & City) Station', 'Brixton Station',
#        'North Sheen Station', 'South Harrow Station', 'Highgate Station',
#        'Twickenham Station', 'Waterloo Station',
#        'Loughborough Junction Station', 'Northfields Station',
#        'Anerley Station', 'Bethnal Green (Mainline) Station',
#        'Motspur Park Station', 'Wood Street Station',
#        'Lancaster Gate Station', 'Harringay Green Lanes Station',
#        'Chiswick Park Station', 'Warren Street Station',
#        'Brondesbury Station', 'Harlesden Station', 'Wallington Station',
#        'Rotherhithe Station', 'East Croydon Station',
#        'Streatham Hill Station', 'Carshalton Beeches Station',
#        'Woolwich Dockyard Station', 'Hanger Lane Station',
#        'Holloway Road Station', 'Earlsfield Station',
#        'Ravenscourt Park Station',
#        'Edgware Road (Circle, District, Hammersmith & City) Station',
#        'Honor Oak Park Station', 'West Hampstead Station',
#        'Fairlop Station', 'Palmers Green Station', 'Tulse Hill Station',
#        'Hampstead Station', 'Hounslow Station', 'South Tottenham Station',
#        'Bromley-by-Bow Station', 'Lebanon Road Tram Stop',
#        'Hackbridge Station', 'Turnpike Lane Station', 'Holborn Station',
#        'Enfield Lock Station', 'Pudding Mill Lane Station',
#        'Sutton (Surrey) Station', 'Colliers Wood Station',
#        'Sudbury Hill Harrow Station', 'Blackhorse Lane Tram Stop',
#        'Kenley Station', 'Gallions Reach Station', 'Southfields Station',
#        'Acton Central Station', 'Island Gardens Station', 'Erith Station',
#        'Gunnersbury Station', 'Finchley Road Station',
#        'Maze Hill Station', 'Winchmore Hill Station', 'Chiswick Station',
#        'Brockley Station', 'Chadwell Heath Station',
#        'Wembley Central Station', 'Richmond Station',
#        'Northumberland Park Station', 'Sudbury & Harrow Road Station',
#        'Woodgrange Park Station', 'Kenton Station',
#        'Bush Hill Park Station', 'Kingston Station',
#        'Lower Sydenham Station', 'Bellingham Station',
#        'Harringay Station', 'South Woodford Station',
#        'Brixton Underground Station', 'Lee Station',
#        'Stamford Hill Station', 'Russell Square Station',
#        'Slade Green Station', 'Arnos Grove Station',
#        'Catford Bridge Station', 'Barnes Bridge Station',
#        'Leyton Midland Road Station', 'Plumstead Station',
#        'Bethnal Green (Underground) Station', 'Homerton Station',
#        'Upney Station', 'Mitcham Junction Station', 'Maryland Station',
#        "Shepherd's Bush (Central) Station", 'Wembley Park Station',
#        'Bruce Grove Station', 'Streatham Common Station',
#        'Raynes Park Station', 'Goldhawk Road Station', 'Victoria Station',
#        'Oval Station', 'Purley Oaks Station',
#        'Totteridge & Whetstone Station', 'Fenchurch Street Station',
#        'Maida Vale Station', 'High Barnet Station', 'Cricklewood Station',
#        'Bromley North Station', 'Ladywell Station', 'Penge East Station',
#        'Eltham Station', 'Emirates Greenwich Peninsula Station',
#        'Covent Garden Station', 'South Hampstead Station',
#        'Penge West Station', 'London Fields Station',
#        'Woodmansterne Station', 'Blackhorse Road Station',
#        'St. Pancras Station', 'Hounslow Central Station',
#        'Northwood Station', 'West Finchley Station',
#        'West Harrow Station', 'Kensal Rise Station', 'Neasden Station',
#        'Stratford International Station', 'Isleworth Station',
#        'South Greenford Station', 'Sydenham Hill Station',
#        'Gipsy Hill Station', 'Queensway Station', 'Kilburn Station',
#        'Turkey Street Station', 'Liverpool Street Station',
#        'Camden Road Station', 'Mornington Crescent Station',
#        'Strawberry Hill Station', 'Gants Hill Station',
#        'Dagenham Dock Station', 'Paddington Station',
#        'Emirates Royal Docks Station', 'Finchley Central Station',
#        'Grange Hill Station', 'Haggerston Station',
#        'Battersea Park Station', 'Barkingside Station', 'Edgware Station',
#        'Colindale Station', 'Lambeth North Station', 'Clapton Station',
#        'Oakwood Station', 'Rainham (Essex) Station', 'Waddon Station',
#        'Tufnell Park Station', 'Crystal Palace Station',
#        'Tolworth Station', 'Forest Gate Station', 'South Ruislip Station',
#        'Dagenham Heathway Station', 'Carshalton Station',
#        'Dagenham East Station', 'Hanwell Station', 'Kidbrooke Station',
#        'Temple Station', 'South Acton Station', 'Barking Station',
#        'Belsize Park Station', 'Leyton Station',
#        'Stoke Newington Station', 'Euston Square Station',
#        'Cutty Sark Station', 'Deptford Bridge Station',
#        'Star Lane Station', 'Addiscombe Tram Stop',
#        'Custom House Station', 'Stamford Brook Station',
#        'Edmonton Green Station',
#        'London Heathrow Airport Terminal 4 Station', 'St. Helier Station',
#        'Eastcote Station', 'Deptford Station', 'Osterley Station',
#        'Thornton Heath Station', 'Blackheath Station',
#        'Wimbledon Park Station', 'Hounslow West Station',
#        'Balham Station', 'North Acton Station', 'Ickenham Station',
#        'George Street Tram Stop', 'Poplar Station', 'Whitton Station',
#        'Devons Road Station', 'Highbury & Islington Station',
#        'Ealing Common Station', 'Shortlands Station',
#        'Hackney Central Station', 'Kentish Town West Station',
#        'Northwick Park Station', 'Leytonstone High Road Station',
#        'Woodford Station', 'Upton Park Station', 'Mill Hill East Station',
#        'Syon Lane Station', 'Canons Park Station',
#        'Wellesley Road Tram Stop', 'Becontree Station',
#        'South Croydon Station', 'Perivale Station',
#        'Finsbury Park Station', 'Newbury Park Station',
#        'Hampton Court Station', 'New Eltham Station',
#        'Sandilands Tram Stop', 'Westminster Station', 'Wapping Station',
#        'East Ham Station', 'Bowes Park Station', 'Tooting Station',
#        'Greenford Station', 'Blackfriars Station',
#        'West Hampstead Thameslink Station', 'Mill Hill Broadway Station',
#        'Park Royal Station', 'Goodmayes Station', 'Malden Manor Station',
#        'Clapham Common Station', 'Wood Green Station',
#        'Goodge Street Station', 'Silver Street Station',
#        'Birkbeck Station', 'Wanstead Park Station',
#        'Mansion House Station', 'Beckenham Hill Station',
#        'All Saints Station', 'Welling Station', 'Northolt Station',
#        'Petts Wood Station', 'South Merton Station',
#        'Ealing Broadway Station', 'Sanderstead Station',
#        'New Cross Station', 'Charing Cross Station',
#        'New Beckenham Station', 'Mitcham Tram Stop',
#        'Clock House Station', 'Bickley Station', 'Wood Lane Station',
#        'Willesden Junction Station', 'West Acton Station',
#        'North Ealing Station', 'Hampstead Heath Station',
#        'Coulsdon Town Station', 'Meridian Water Station',
#        'Enfield Chase Station', 'West Wickham Station', 'Denham Station',
#        'Sydenham Station', 'Hyde Park Corner Station',
#        'Boston Manor Station', 'Oakleigh Park Station',
#        'Alexandra Palace Station', 'Falconwood Station',
#        'Morden South Station', 'West Sutton Station',
#        'Sudbury Hill Station', 'Hainault Station', 'Royal Albert Station',
#        'North Dulwich Station', 'Canary Wharf Station', 'Aldgate Station',
#        'Coombe Lane Tram Stop', 'Grove Park Station', 'Orpington Station',
#        'Gordon Hill Station', 'Wanstead Station', 'Crofton Park Station',
#        'Brimsdown Station', 'Church Street Tram Stop',
#        'Belgrave Walk Tram Stop', 'Ruislip Manor Station',
#        'Chessington South Station', 'South Kenton Station',
#        'Bounds Green Station', 'Notting Hill Gate Station',
#        'Hatch End Station', 'Nunhead Station', 'Bexleyheath Station',
#        'Hornchurch Station', 'Cannon Street Station',
#        'Heathrow Terminal 5 Station', 'St. James Street Station',
#        'Riddlesdown Station', 'Walthamstow Queens Road Station',
#        'White Hart Lane Station', 'Lea Bridge', 'Ampere Way Tram Stop',
#        'Ruislip Station', 'Chislehurst Station',
#        'Therapia Lane Tram Stop', 'Manor Park Station', 'Arena Tram Stop',
#        'Leytonstone Station', 'Chelsfield Station',
#        'Hatton Cross Station', 'Clapham High Street Station',
#        'Cheam Station', 'City Thameslink Station', 'Moorgate Station',
#        'Chessington North Station', 'Dalston Junction Station',
#        'Catford Station', 'Drayton Green Station',
#        'Upminster Bridge Station', 'Bow Church Station',
#        'Addington Village Tram Stop', 'Belvedere Station',
#        'Roding Valley Station', 'Upminster Station',
#        'North Wembley Station', 'Elm Park Station', 'Gospel Oak Station',
#        'New Addington Tram Stop', 'Morden Station', 'Abbey Road Station',
#        'Hampton Station', 'Ruislip Gardens Station', 'Woodside Tram Stop',
#        'Euston Station', 'Tower Gateway Station', 'Kempton Park',
#        'North Greenwich Station', 'Morden Road Tram Stop',
#        'South Ealing Station', 'Phipps Bridge Tram Stop',
#        'Grange Park Station', "King Henry's Drive Tram Stop",
#        'Crayford Station', 'Elmers End Station',
#        'Elstree & Borehamwood Station', 'London City Airport Station',
#        'Crews Hill Station', 'Chigwell Station', "St. John's Station",
#        'Embankment Station', 'Sudbury Town Station',
#        'Beckton Park Station', 'Harrington Rd Tram Stop',
#        'Beddington Lane Tram Stop', 'Kent House Station',
#        'Cyprus Station', 'Centrale Tram Stop', "St. Paul's Station",
#        'Beckenham Road Tram Stop', 'Gravel Hill Tram Stop',
#        'Waddon Marsh Tram Stop', 'Knockholt Station',
#        'Reeves Corner Tram Stop', 'Chipstead Station',
#        'High Street Kensington Station'], dtype=object)

# %%
for col in ["nearest_station1_name", "nearest_station2_name", "nearest_station3_name", "borough", "district"]:
    file[col] = file[col].astype(str).str.replace("'", "`")

# %%
file["district"]
# Out:
# 0        Chiswick Riverside
# 1                 Cleveland
# 2              St. George`s
# 3         Wandsworth Common
# 4                St. Mary`s
#                 ...
# 28483        Royal Hospital
# 28484            Queenstown
# 28485                 Grove
# 28486              West End
# 28487         Garden Suburb
# Name: district, Length: 28488, dtype: object

# %%
file["nearest_station1_name"].unique()
# Out:
# array(["'Kew Bridge Station'", "'Castle Bar Park Station'",
#        "'Elephant & Castle (Bakerloo) Station'", "'Tooting Bec Station'",
#        "'Angel Station'", "'Old Street Station'", "'Hillingdon Station'",
#        "'Arsenal Station'", "'Aldgate East Station'",
#        "'Shadwell Station'", "'Royal Victoria Station'",
#        "'South Kensington Station'", "'Berrylands Station'",
#        "'St. John''s Wood Station'", "'Eden Park Station'",
#        "'Harold Wood Station'", "'Tottenham Court Road Station'",
#        "'Barons Court Station'", "'Brondesbury Park Station'",
#        "'Bexley Station'", "'Pontoon Dock Station'",
#        "'Westbourne Park Station'", "'Preston Road Station'",
#        "'Marble Arch Station'", "'Oxford Circus Station'",
#        "'Hounslow East Station'", "'Hayes & Harlington Station'",
#        "'Uxbridge Station'", "'Southall Station'",
#        "'Hackney Downs Station'", "'Wimbledon Chase Station'",
#        "'Elephant & Castle Station'", "'Waterloo East Station'",
#        "'Lloyd Park Tram Stop'", "'Snaresbrook Station'",
#        "'Kilburn High Road Station'", "'Seven Sisters Station'",
#        "'West Ruislip Station'", "'Nine Elms Station'",
#        "'East Finchley Station'", "'Kew Gardens Station'",
#        "'Camden Town Station'", "'Marylebone Station'",
#        "'Acton Main Line Station'", "'Mile End Station'",
#        "'Reedham (Surrey) Station'", "'Redbridge Station'",
#        "'Mudchute Station'", "'St. James''s Park Station'",
#        "'West Drayton Station'", "'Alperton Station'",
#        "'Crossharbour & London Arena Station'", "'Langdon Park Station'",
#        "'Burnt Oak Station'", "'Dollis Hill Station'",
#        "'Queenstown Road (Battersea) Station'",
#        "'Imperial Wharf Station'", "'Pinner Station'",
#        "'Sutton Common Station'", "'Belmont Station'",
#        "'West Kensington Station'", "'Elverson Road Station'",
#        "'Knightsbridge Station'", "'Queensbury Station'",
#        "'Feltham Station'", "'Crouch Hill Station'",
#        "'Surrey Quays Station'", "'Great Portland Street Station'",
#        "'South Bermondsey Station'", "'Monument Station'",
#        "'Enfield Town Station'", "'Mitcham Eastfields Station'",
#        "'Fulwell Station'", "'Hornsey Station'", "'Hendon Station'",
#        "'Essex Road Station'", "'Swiss Cottage Station'",
#        "'Edgware Road (Bakerloo) Station'", "'Westferry Station'",
#        "'Hither Green Station'", "'London Bridge Station'",
#        "'Hampton Wick Station'", "'Brent Cross West Station'",
#        "'Avenue Road Tram Stop'", "'Gloucester Road Station'",
#        "'Selhurst Station'", "'Sidcup Station'", "'Brentford Station'",
#        "'Whitechapel Station'", "'Kensal Green Station'",
#        "'Harrow-on-the-Hill Station'", "'Kennington Station'",
#        "'Elmstead Woods Station'", "'Blackwall Station'",
#        "'Headstone Lane Station'", "'Hoxton Station'",
#        "'Willesden Green Station'", "'St. Margarets Station'",
#        "'North Harrow Station'", "'Manor House Station'",
#        "'Southwark Station'", "'West Ealing Station'",
#        "'Clapham North Station'", "'Green Park Station'",
#        "'London Heathrow Airport Terminals 1, 2 & 3 Station'",
#        "'Ravensbourne Station'", "'Plaistow Station'",
#        "'Barbican Station'", "'Tooting Broadway Station'",
#        "'Stepney Green Station'", "'Warwick Avenue Station'",
#        "'Tottenham Hale Station'", "'Drayton Park Station'",
#        "'Wimbledon Station'", "'Herne Hill Station'",
#        "'East Acton Station'", "'South Quay Station'",
#        "'Stanmore Station'", "'West Dulwich Station'",
#        "'Sloane Square Station'", "'Fulham Broadway Station'",
#        "'Finchley Road & Frognal Station'", "'Canning Town Station'",
#        "'Emerson Park Station'", "'West India Quay Station'",
#        "'New Cross Gate Station'", "'Leicester Square Station'",
#        "'Stratford High Street Station'", "'White City Station'",
#        "'Haydons Road Station'", "'Ilford Station'",
#        "'Kentish Town Station'", "'Pimlico Station'",
#        "'Caledonian Road Station'", "'Hackney Wick Station'",
#        "'Harrow & Wealdstone Station'", "'Limehouse Station'",
#        "'Coulsdon South Station'", "'Vauxhall Station'",
#        "'Wandle Park Tram Stop'", "'Beckenham Junction Station'",
#        "'East Dulwich Station'", "'Southgate Station'",
#        "'Chancery Lane Station'", "'Bayswater Station'",
#        "'Brent Cross Station'", "'Barking Riverside Station'",
#        "'Wandsworth Common Station'", "'Clapham South Station'",
#        "'Queens Road Peckham Station'", "'Mortlake Station'",
#        "'Walthamstow Central Station'", "'Merton Park Tram Stop'",
#        "'Charlton Station'", "'Dalston Kingsland Station'",
#        "'Peckham Rye Station'", "'Purley Station'",
#        "'Wandsworth Road Station'", "'Northwood Hills Station'",
#        "'Woolwich Arsenal Station'", "'East Putney Station'",
#        "'Farringdon Station'", "'Bermondsey Station'",
#        "'Prince Regent Station'", "'Earls Court Station'",
#        "'South Wimbledon Station'", "'Putney Station'",
#        "'Turnham Green Station'", "'Wembley Stadium Station'",
#        "'Baker Street Station'", "'Dundonald Road Tram Stop'",
#        "'Norbury Station'", "'Cockfosters Station'",
#        "'Queen''s Park Station'", "'St. Mary Cray Station'",
#        "'Bow Road Station'", "'King George V Station'",
#        "'Canonbury Station'", "'Hendon Central Station'",
#        "'Clapham Junction Station'", "'Putney Bridge Station'",
#        "'Stratford Station'",
#        "'Hammersmith (District & Piccadilly) Station'",
#        "'Lewisham Station'", "'Ponders End Station'",
#        "'Hadley Wood Station'", "'Canada Water Station'",
#        "'Worcester Park Station'", "'Surbiton Station'",
#        "'Piccadilly Circus Station'", "'Bond Street Station'",
#        "'Norbiton Station'", "'Hayes Station'",
#        "'Cambridge Heath Station'", "'Kingsbury Station'",
#        "'Caledonian Road & Barnsbury Station'", "'Woolwich Station'",
#        "'Westcombe Park Station'", "'Heron Quays Station'",
#        "'Chingford Station'", "'West Ham Station'",
#        "'Wandsworth Town Station'", "'Stonebridge Park Station'",
#        "'Norwood Junction Station'", "'Woodside Park Station'",
#        "'West Norwood Station'", "'Gidea Park Station'",
#        "'Parsons Green Station'", "'Seven Kings Station'",
#        "'Sundridge Park Station'", "'Borough Station'",
#        "'Teddington Station'", "'West Silvertown Station'",
#        "'West Brompton Station'", "'Albany Park Station'",
#        "'Kensington Olympia Station'", "'Kilburn Park Station'",
#        "'Regent''s Park Station'", "'Romford Station'",
#        "'Kings Cross Thameslink Station'",
#        "'Shepherd''s Bush (Hammersmith & City) Station'",
#        "'Bromley South Station'", "'East India Station'",
#        "'Highams Park Station'", "'Shoreditch High Street Station'",
#        "'Rayners Lane Station'", "'Mottingham Station'",
#        "'West Croydon Station'", "'Tower Hill Station'",
#        "'Northolt Park Station'", "'Denmark Hill Station'",
#        "'Stockwell Station'", "'Upper Holloway Station'",
#        "'Royal Oak Station'", "'Abbey Wood Station'",
#        "'New Southgate Station'", "'Rectory Road Station'",
#        "'Barnes Station'", "'Battersea Power Underground Station'",
#        "'New Malden Station'", "'Southbury Station'", "'Archway Station'",
#        "'Acton Town Station'", "'Beckton Station'",
#        "'Forest Hill Station'", "'Chalk Farm Station'",
#        "'Greenwich DLR Station'", "'King''s Cross Station'",
#        "'Streatham Station'", "'Barnehurst Station'",
#        "'Golders Green Station'",
#        "'Hammersmith (Hammersmith & City) Station'", "'Brixton Station'",
#        "'North Sheen Station'", "'South Harrow Station'",
#        "'Highgate Station'", "'Twickenham Station'", "'Waterloo Station'",
#        "'Loughborough Junction Station'", "'Northfields Station'",
#        "'Anerley Station'", "'Bethnal Green (Mainline) Station'",
#        "'Motspur Park Station'", "'Wood Street Station'",
#        "'Lancaster Gate Station'", "'Harringay Green Lanes Station'",
#        "'Chiswick Park Station'", "'Warren Street Station'",
#        "'Brondesbury Station'", "'Harlesden Station'",
#        "'Wallington Station'", "'Rotherhithe Station'",
#        "'East Croydon Station'", "'Streatham Hill Station'",
#        "'Carshalton Beeches Station'", "'Woolwich Dockyard Station'",
#        "'Hanger Lane Station'", "'Holloway Road Station'",
#        "'Earlsfield Station'", "'Ravenscourt Park Station'",
#        "'Edgware Road (Circle, District, Hammersmith & City) Station'",
#        "'Honor Oak Park Station'", "'West Hampstead Station'",
#        "'Fairlop Station'", "'Palmers Green Station'",
#        "'Tulse Hill Station'", "'Hampstead Station'",
#        "'Hounslow Station'", "'South Tottenham Station'",
#        "'Bromley-by-Bow Station'", "'Lebanon Road Tram Stop'",
#        "'Hackbridge Station'", "'Turnpike Lane Station'",
#        "'Holborn Station'", "'Enfield Lock Station'",
#        "'Pudding Mill Lane Station'", "'Sutton (Surrey) Station'",
#        "'Colliers Wood Station'", "'Sudbury Hill Harrow Station'",
#        "'Blackhorse Lane Tram Stop'", "'Kenley Station'",
#        "'Gallions Reach Station'", "'Southfields Station'",
#        "'Acton Central Station'", "'Island Gardens Station'",
#        "'Erith Station'", "'Gunnersbury Station'",
#        "'Finchley Road Station'", "'Maze Hill Station'",
#        "'Winchmore Hill Station'", "'Chiswick Station'",
#        "'Brockley Station'", "'Chadwell Heath Station'",
#        "'Wembley Central Station'", "'Richmond Station'",
#        "'Northumberland Park Station'", "'Sudbury & Harrow Road Station'",
#        "'Woodgrange Park Station'", "'Kenton Station'",
#        "'Bush Hill Park Station'", "'Kingston Station'",
#        "'Lower Sydenham Station'", "'Bellingham Station'",
#        "'Harringay Station'", "'South Woodford Station'",
#        "'Brixton Underground Station'", "'Lee Station'",
#        "'Stamford Hill Station'", "'Russell Square Station'",
#        "'Slade Green Station'", "'Arnos Grove Station'",
#        "'Catford Bridge Station'", "'Barnes Bridge Station'",
#        "'Leyton Midland Road Station'", "'Plumstead Station'",
#        "'Bethnal Green (Underground) Station'", "'Homerton Station'",
#        "'Upney Station'", "'Mitcham Junction Station'",
#        "'Maryland Station'", "'Shepherd''s Bush (Central) Station'",
#        "'Wembley Park Station'", "'Bruce Grove Station'",
#        "'Streatham Common Station'", "'Raynes Park Station'",
#        "'Goldhawk Road Station'", "'Victoria Station'", "'Oval Station'",
#        "'Purley Oaks Station'", "'Totteridge & Whetstone Station'",
#        "'Fenchurch Street Station'", "'Maida Vale Station'",
#        "'High Barnet Station'", "'Cricklewood Station'",
#        "'Bromley North Station'", "'Ladywell Station'",
#        "'Penge East Station'", "'Eltham Station'",
#        "'Emirates Greenwich Peninsula Station'",
#        "'Covent Garden Station'", "'South Hampstead Station'",
#        "'Penge West Station'", "'London Fields Station'",
#        "'Woodmansterne Station'", "'Blackhorse Road Station'",
#        "'St. Pancras Station'", "'Hounslow Central Station'",
#        "'Northwood Station'", "'West Finchley Station'",
#        "'West Harrow Station'", "'Kensal Rise Station'",
#        "'Neasden Station'", "'Stratford International Station'",
#        "'Isleworth Station'", "'South Greenford Station'",
#        "'Sydenham Hill Station'", "'Gipsy Hill Station'",
#        "'Queensway Station'", "'Kilburn Station'",
#        "'Turkey Street Station'", "'Liverpool Street Station'",
#        "'Camden Road Station'", "'Mornington Crescent Station'",
#        "'Strawberry Hill Station'", "'Gants Hill Station'",
#        "'Dagenham Dock Station'", "'Paddington Station'",
#        "'Emirates Royal Docks Station'", "'Finchley Central Station'",
#        "'Grange Hill Station'", "'Haggerston Station'",
#        "'Battersea Park Station'", "'Barkingside Station'",
#        "'Edgware Station'", "'Colindale Station'",
#        "'Lambeth North Station'", "'Clapton Station'",
#        "'Oakwood Station'", "'Rainham (Essex) Station'",
#        "'Waddon Station'", "'Tufnell Park Station'",
#        "'Crystal Palace Station'", "'Tolworth Station'",
#        "'Forest Gate Station'", "'South Ruislip Station'",
#        "'Dagenham Heathway Station'", "'Carshalton Station'",
#        "'Dagenham East Station'", "'Hanwell Station'",
#        "'Kidbrooke Station'", "'Temple Station'", "'South Acton Station'",
#        "'Barking Station'", "'Belsize Park Station'", "'Leyton Station'",
#        "'Stoke Newington Station'", "'Euston Square Station'",
#        "'Cutty Sark Station'", "'Deptford Bridge Station'",
#        "'Star Lane Station'", "'Addiscombe Tram Stop'",
#        "'Custom House Station'", "'Stamford Brook Station'",
#        "'Edmonton Green Station'",
#        "'London Heathrow Airport Terminal 4 Station'",
#        "'St. Helier Station'", "'Eastcote Station'", "'Deptford Station'",
#        "'Osterley Station'", "'Thornton Heath Station'",
#        "'Blackheath Station'", "'Wimbledon Park Station'",
#        "'Hounslow West Station'", "'Balham Station'",
#        "'North Acton Station'", "'Ickenham Station'",
#        "'George Street Tram Stop'", "'Poplar Station'",
#        "'Whitton Station'", "'Devons Road Station'",
#        "'Highbury & Islington Station'", "'Ealing Common Station'",
#        "'Shortlands Station'", "'Hackney Central Station'",
#        "'Kentish Town West Station'", "'Northwick Park Station'",
#        "'Leytonstone High Road Station'", "'Woodford Station'",
#        "'Upton Park Station'", "'Mill Hill East Station'",
#        "'Syon Lane Station'", "'Canons Park Station'",
#        "'Wellesley Road Tram Stop'", "'Becontree Station'",
#        "'South Croydon Station'", "'Perivale Station'",
#        "'Finsbury Park Station'", "'Newbury Park Station'",
#        "'Hampton Court Station'", "'New Eltham Station'",
#        "'Sandilands Tram Stop'", "'Westminster Station'",
#        "'Wapping Station'", "'East Ham Station'", "'Bowes Park Station'",
#        "'Tooting Station'", "'Greenford Station'",
#        "'Blackfriars Station'", "'West Hampstead Thameslink Station'",
#        "'Mill Hill Broadway Station'", "'Park Royal Station'",
#        "'Goodmayes Station'", "'Malden Manor Station'",
#        "'Clapham Common Station'", "'Wood Green Station'",
#        "'Goodge Street Station'", "'Silver Street Station'",
#        "'Birkbeck Station'", "'Wanstead Park Station'",
#        "'Mansion House Station'", "'Beckenham Hill Station'",
#        "'All Saints Station'", "'Welling Station'", "'Northolt Station'",
#        "'Petts Wood Station'", "'South Merton Station'",
#        "'Ealing Broadway Station'", "'Sanderstead Station'",
#        "'New Cross Station'", "'Charing Cross Station'",
#        "'New Beckenham Station'", "'Mitcham Tram Stop'",
#        "'Clock House Station'", "'Bickley Station'",
#        "'Wood Lane Station'", "'Willesden Junction Station'",
#        "'West Acton Station'", "'North Ealing Station'",
#        "'Hampstead Heath Station'", "'Coulsdon Town Station'",
#        "'Meridian Water Station'", "'Enfield Chase Station'",
#        "'West Wickham Station'", "'Denham Station'", "'Sydenham Station'",
#        "'Hyde Park Corner Station'", "'Boston Manor Station'",
#        "'Oakleigh Park Station'", "'Alexandra Palace Station'",
#        "'Falconwood Station'", "'Morden South Station'",
#        "'West Sutton Station'", "'Sudbury Hill Station'",
#        "'Hainault Station'", "'Royal Albert Station'",
#        "'North Dulwich Station'", "'Canary Wharf Station'",
#        "'Aldgate Station'", "'Coombe Lane Tram Stop'",
#        "'Grove Park Station'", "'Orpington Station'",
#        "'Gordon Hill Station'", "'Wanstead Station'",
#        "'Crofton Park Station'", "'Brimsdown Station'",
#        "'Church Street Tram Stop'", "'Belgrave Walk Tram Stop'",
#        "'Ruislip Manor Station'", "'Chessington South Station'",
#        "'South Kenton Station'", "'Bounds Green Station'",
#        "'Notting Hill Gate Station'", "'Hatch End Station'",
#        "'Nunhead Station'", "'Bexleyheath Station'",
#        "'Hornchurch Station'", "'Cannon Street Station'",
#        "'Heathrow Terminal 5 Station'", "'St. James Street Station'",
#        "'Riddlesdown Station'", "'Walthamstow Queens Road Station'",
#        "'White Hart Lane Station'", "'Lea Bridge'",
#        "'Ampere Way Tram Stop'", "'Ruislip Station'",
#        "'Chislehurst Station'", "'Therapia Lane Tram Stop'",
#        "'Manor Park Station'", "'Arena Tram Stop'",
#        "'Leytonstone Station'", "'Chelsfield Station'",
#        "'Hatton Cross Station'", "'Clapham High Street Station'",
#        "'Cheam Station'", "'City Thameslink Station'",
#        "'Moorgate Station'", "'Chessington North Station'",
#        "'Dalston Junction Station'", "'Catford Station'",
#        "'Drayton Green Station'", "'Upminster Bridge Station'",
#        "'Bow Church Station'", "'Addington Village Tram Stop'",
#        "'Belvedere Station'", "'Roding Valley Station'",
#        "'Upminster Station'", "'North Wembley Station'",
#        "'Elm Park Station'", "'Gospel Oak Station'",
#        "'New Addington Tram Stop'", "'Morden Station'",
#        "'Abbey Road Station'", "'Hampton Station'",
#        "'Ruislip Gardens Station'", "'Woodside Tram Stop'",
#        "'Euston Station'", "'Tower Gateway Station'", "'Kempton Park'",
#        "'North Greenwich Station'", "'Morden Road Tram Stop'",
#        "'South Ealing Station'", "'Phipps Bridge Tram Stop'",
#        "'Grange Park Station'", "'King Henry''s Drive Tram Stop'",
#        "'Crayford Station'", "'Elmers End Station'",
#        "'Elstree & Borehamwood Station'", "'London City Airport Station'",
#        "'Crews Hill Station'", "'Chigwell Station'",
#        "'St. John''s Station'", "'Embankment Station'",
#        "'Sudbury Town Station'", "'Beckton Park Station'",
#        "'Harrington Rd Tram Stop'", "'Beddington Lane Tram Stop'",
#        "'Kent House Station'", "'Cyprus Station'", "'Centrale Tram Stop'",
#        "'St. Paul''s Station'", "'Beckenham Road Tram Stop'",
#        "'Gravel Hill Tram Stop'", "'Waddon Marsh Tram Stop'",
#        "'Knockholt Station'", "'Reeves Corner Tram Stop'",
#        "'Chipstead Station'", "'High Street Kensington Station'"],
#       dtype=object)

# %%
file[file["nearest_station1_name"] == 'King`s Cross Station']
# Out:
#        Unnamed: 0.1  Unnamed: 0         id  \
# 411             411         411  150639281
# 580             580         580  156347375
# 1396           1396        1396  153623816
# 1472           1472        1472  156281351
# 1916           1916        1916  155859062
# 3318           3318        3318  155804957
# 3792           3792        3792  152555120
# 3964           3964        3964  149520500
# 4574           4574        4574  152291423
# 7178           7178        7178  156354206
# 7830           7830        7830  156120875
# 8072           8072        8072  144287894
# 10562         10562       10562  145209713
# 10767         10767       10767  156281180
# 13063         13063       13063  156300029
# 13875         13875       13875  152115512
# 15598         15598       15598  156393836
# 16352         16352       16352  156380960
# 16872         16872       16872  156085196
# 17493         17493       17493  156032333
# 19336         19336       19336  156100262
# 19712         19712       19712  155803088
# 19966         19966       19966  156340640
# 21830         21830       21830  155584754
# 22208         22208       22208   74417414
# 22264         22264       22264  155593355
# 25220         25220       25220  154311560
# 25795         25795       25795  139968422
#
#                                                    title  \
# 411    Studio flat for rent in Plimsoll Building, Han...
# 580    1 bedroom apartment for rent in Luma House, Le...
# 1396     2 bedroom flat for rent in London, London, WC1H
# 1472   1 bedroom flat for rent in Plimsoll Building, ...
# 1916   1 bedroom flat for rent in Lewis Cubitt Park, ...
# 3318        1 bedroom apartment for rent in York Way, N1
# 3792   2 bedroom apartment for rent in Plimsoll Build...
# 3964   2 bedroom apartment for rent in Gasholders Bui...
# 4574   3 bedroom flat for rent in Lewis Cubitt Square...
# 7178   2 bedroom flat for rent in Lewis Cubitt Park, ...
# 7830   1 bedroom flat for rent in Plimsoll Building, ...
# 8072   2 bedroom apartment for rent in Handyside Stre...
# 10562  1 bedroom apartment for rent in Gasholders Bui...
# 10767  3 bedroom flat for rent in Gasholders Building...
# 13063  2 bedroom flat for rent in Capella Building, O...
# 13875  2 bedroom flat for rent in Handyside Street, B...
# 15598  2 bedroom flat for rent in Capella Court, King...
# 16352  2 bedroom flat for rent in Capella Court, King...
# 16872  1 bedroom flat for rent in Plimsoll Building, ...
# 17493  2 bedroom flat for rent in Lewis Cubitt Walk, ...
# 19336  2 bedroom apartment for rent in Capella Court,...
# 19712  1 bedroom flat for rent in Handyside Street, K...
# 19966  2 bedroom flat for rent in Plimsoll Building, ...
# 21830      2 bedroom apartment for rent in Plimsoll, N1C
# 22208  1 bedroom apartment for rent in Birkenhead Str...
# 22264  1 bedroom flat for rent in Argyle street, King...
# 25220  1 bedroom apartment for rent in Lewis Cubitt P...
# 25795  1 bedroom apartment for rent in Gasholders Bui...
#
#                                          display_address postcode_outcode  \
# 411     Plimsoll Building, Handyside Street, London, N1C              N1C
# 580    Luma House, Lewis Cubitt Walk, Kings Cross, Lo...              N1C
# 1396                                London, London, WC1H             WC1H
# 1472    Plimsoll Building, Handyside Street, London, N1C              N1C
# 1916         Lewis Cubitt Park, Kings Cross, London, N1C              N1C
# 3318                                        York Way, N1               N1
# 3792             Plimsoll Building, King's Cross, London              N1C
# 3964   Gasholders Building, 1 Lewis Cubitt Square, Lo...              N1C
# 4574                Lewis Cubitt Square, Coal Drops Yard              N1C
# 7178                      Lewis Cubitt Park, London, N1C              N1C
# 7830    Plimsoll Building, Handyside Street, London, N1C              N1C
# 8072                       Handyside Street, London, N1C              N1C
# 10562  Gasholders Building, King's Cross, Islington, ...              N1C
# 10767  Gasholders Building, Lewis Cubitt Square, Lond...              N1C
# 13063  Capella Building, One Lewis Cubitt Park, Londo...              N1C
# 13875                       Handyside Street, Bloomsbury              N1C
# 15598           Capella Court, King's Cross, London, N1C              N1C
# 16352           Capella Court, King's Cross, London, N1C              N1C
# 16872   Plimsoll Building, Handyside Street, London, N1C              N1C
# 17493                     Lewis Cubitt Walk, London, N1C              N1C
# 19336            Capella Court, Kings Cross, London, N1C              N1C
# 19712        Handyside Street, King's Cross, London, N1C              N1C
# 19966  Plimsoll Building, 1 Handyside Street, London,...              N1C
# 21830                                           Plimsoll              N1C
# 22208                    Birkenhead Street, London, WC1H             WC1H
# 22264          Argyle street, King's Cross, London, WC1H             WC1H
# 25220                     Lewis Cubitt Park, London, N1C              N1C
# 25795  Gasholders Building, 1 Lewis Cubitt Square, Lo...              N1C
#
#       postcode_incode  bathrooms  bedrooms property_type  ...    borough  \
# 411               4BP          1         1         other  ...     Camden
# 580               4EJ          1         1     Apartment  ...     Camden
# 1396              8DT          1         2          Flat  ...     Camden
# 1472              4BQ          1         1          Flat  ...     Camden
# 1916              4EJ          1         1          Flat  ...     Camden
# 3318              9AA          1         1     Apartment  ...  Islington
# 3792              4BQ          2         2     Apartment  ...     Camden
# 3964              4BY          2         2     Apartment  ...     Camden
# 4574              4BX          3         3          Flat  ...     Camden
# 7178              4EJ          2         2          Flat  ...     Camden
# 7830              4BR          1         1          Flat  ...     Camden
# 8072              4BP          1         2     Apartment  ...     Camden
# 10562             4BY          1         1     Apartment  ...     Camden
# 10767             4BW          3         3          Flat  ...     Camden
# 13063             4EJ          2         2          Flat  ...     Camden
# 13875             4BQ          2         2          Flat  ...     Camden
# 15598             4EL          3         2          Flat  ...     Camden
# 16352             4EJ          2         2          Flat  ...     Camden
# 16872             4BR          1         1          Flat  ...     Camden
# 17493             4DT          2         2          Flat  ...     Camden
# 19336             4EJ          2         2     Apartment  ...     Camden
# 19712             4BQ          1         1          Flat  ...     Camden
# 19966             4BR          2         2          Flat  ...     Camden
# 21830             4BQ          2         2     Apartment  ...     Camden
# 22208             8BB          1         1     Apartment  ...     Camden
# 22264             8ER          1         1          Flat  ...     Camden
# 25220             4EL          1         1     Apartment  ...     Camden
# 25795             4BY          1         1     Apartment  ...     Camden
#
#        travel_zone  distance_to_center_km spatial_index noise_level_class  \
# 411              2               2.102341       17953.0           no_data
# 580              2               2.165319       26995.0       medium-high
# 1396             1               1.461001        3742.0            medium
# 1472             2               2.053327       17953.0           no_data
# 1916             2               1.839465        2561.0       medium-high
# 3318             1               1.670158       23483.0              high
# 3792             2               2.113346       17953.0           no_data
# 3964             2               2.068746       17953.0           no_data
# 4574             2               2.036640       17953.0           no_data
# 7178             2               2.167057       26995.0       medium-high
# 7830             2               2.113415       17953.0           no_data
# 8072             2               2.102341       17953.0           no_data
# 10562            2               2.038638       17953.0           no_data
# 10767            2               2.036641       17953.0           no_data
# 13063            2               2.167057       26995.0       medium-high
# 13875            2               2.092764       26995.0       medium-high
# 15598            2               2.172439       26995.0       medium-high
# 16352            2               2.080812       26995.0       medium-high
# 16872            2               2.113415       17953.0           no_data
# 17493            2               2.136962       26995.0       medium-high
# 19336            2               2.167116       26995.0       medium-high
# 19712            2               2.013336       26039.0        medium-low
# 19966            2               2.113415       17953.0           no_data
# 21830            2               2.113558       17953.0           no_data
# 22208            1               1.584817       23483.0              high
# 22264            1               1.469504        3742.0            medium
# 25220            2               2.154619       17953.0           no_data
# 25795            2               2.068746       17953.0           no_data
#
#        zone_hex                                        description  \
# 411      Zone 2  Please Quote ID: 17575A spacious garden facing...
# 580      Zone 2  Exceptional 1-Bedroom Apartment in Kings Cross...
# 1396     Zone 1  Property Reference: 1132799.ESTATE AGENCY OR P...
# 1472     Zone 2  A modern, one bedroom apartment located on the...
# 1916     Zone 1  A brand new luxury one bedroom apartment with ...
# 3318     Zone 1  Available December 2024, a top floor one bedro...
# 3792     Zone 2  A stunning modern two-bedroom apartment, locat...
# 3964     Zone 2  EGRE are excited to offer this twobedroom apar...
# 4574     Zone 2  This stunning three-bedroom, three-bathroom ap...
# 7178     Zone 2  Brand New luxury two-bedroom flat to rent in t...
# 7830     Zone 2  This one bedroom apartment situated in the Pli...
# 8072     Zone 2  We are proud to present this beautiful 2 bedro...
# 10562    Zone 2  Please Quote ASP ID: 52240A luxurious Studio a...
# 10767    Zone 2  Built within a refurbished triplet of Grade II...
# 13063    Zone 2  Clifton Property Partners are delighted to be ...
# 13875    Zone 2  Exceptionally finished two bedroom apartment o...
# 15598    Zone 2  Welcome to the Capella Building, an architectu...
# 16352    Zone 2  Welcome to the Capella Building, an architectu...
# 16872    Zone 2  A well presented one bedroom apartment situate...
# 17493    Zone 2  Property Reference: 2298286.This exceptional p...
# 19336    Zone 2  This beautifully crafted modern TWO BEDROOM  a...
# 19712    Zone 1  LONG LET. A luxurious 1 bedroom apartment situ...
# 19966    Zone 2  A modern two bedroom apartment situated on the...
# 21830    Zone 2  Daniel Ford Estates are delighted to present t...
# 22208    Zone 1  Situated on the top floor this 1 bedroom apart...
# 22264    Zone 1  LONG LET. Well presented one bedroom apartment...
# 25220    Zone 2  FURNISHED OR UNFURNISHED, THE LANDLORD IS FLEX...
# 25795    Zone 2  EGRE are excited to offer this one-bedroom apa...
#
#       predicted_price pricing_index                     district
# 411       2698.843668      1.111587  St. Pancras and Somers Town
# 580       3078.515993      0.950133  St. Pancras and Somers Town
# 1396      2385.356891      0.908040                 King`s Cross
# 1472      3056.623029      0.921605  St. Pancras and Somers Town
# 1916      3316.482768      0.934122  St. Pancras and Somers Town
# 3318      2478.244693      0.907901                   Caledonian
# 3792      4417.400724      0.927016  St. Pancras and Somers Town
# 3964      4665.845899      1.093049  St. Pancras and Somers Town
# 4574      5614.512786      1.282035  St. Pancras and Somers Town
# 7178      4636.500619      0.817858  St. Pancras and Somers Town
# 7830      3114.002331      0.963069  St. Pancras and Somers Town
# 8072      3947.935549      1.042824  St. Pancras and Somers Town
# 10562     3564.178840      1.122278  St. Pancras and Somers Town
# 10767     5710.049818      1.138344  St. Pancras and Somers Town
# 13063     5377.263539      1.410197  St. Pancras and Somers Town
# 13875     4138.336444      0.966572  St. Pancras and Somers Town
# 15598     6400.859111      1.184685  St. Pancras and Somers Town
# 16352     4115.430181      0.921410  St. Pancras and Somers Town
# 16872     3071.169356      0.987572  St. Pancras and Somers Town
# 17493     4570.187050      0.853357  St. Pancras and Somers Town
# 19336     4383.143693      0.864904  St. Pancras and Somers Town
# 19712     2623.310341      1.073834  St. Pancras and Somers Town
# 19966     4350.283538      0.971201  St. Pancras and Somers Town
# 21830     4387.920454      1.093912  St. Pancras and Somers Town
# 22208     3200.902976      1.083132                 King`s Cross
# 22264     1751.400937      1.224734                 King`s Cross
# 25220     3116.558297      1.077471  St. Pancras and Somers Town
# 25795     3519.996588      1.353979  St. Pancras and Somers Town
#
# [28 rows x 45 columns]

# %%
def safe_user_query(q: str) -> str:
    return q.replace("'", "`").replace("’", "`").replace("‘", "`")

# %%
safe_user_query("Find flats for rent with parking available near King's Cross in London")
# Out:
# 'Find flats for rent with parking available near King`s Cross in London'

# %%
df_pai = pai.DataFrame(file)

# %%
df_ai = pai.create(
    path="new-bot/rental-data-london4",
    df=df_pai,
    description="London real estate property listings with pricing, size, location, station proximity, and noise levels",
    columns=[
        {"name": "id", "type": "string", "description": "Unique identifier for each property listing"},
        {"name": "title", "type": "string", "description": "Listing title"},
        {"name": "display_address", "type": "string", "description": "Readable address of the property"},
        {"name": "postcode_outcode", "type": "string", "description": "Outcode part of the UK postcode"},
        {"name": "postcode_incode", "type": "string", "description": "Incode part of the UK postcode"},
        {"name": "bathrooms", "type": "integer", "description": "Number of bathrooms"},
        {"name": "bedrooms", "type": "integer", "description": "Number of bedrooms"},
        {"name": "property_type", "type": "string", "description": "Type of property (flat, apartment, house, etc.)"},
        {"name": "price_gbp", "type": "float", "description": "Listed price in GBP"},
        {"name": "secondary_price_gbp", "type": "float", "description": "Secondary listing price (e.g. weekly rent) in GBP"},
        {"name": "deposit_included_or_not", "type": "string", "description": "Deposit included or (e.g "},
        {"name": "let_type", "type": "string", "description": "Letting type (short term, long term)"},
        {"name": "furnish_type", "type": "string", "description": "Furnishing type (furnished, unfurnished, part furnished)"},
        {"name": "council_tax_exempt", "type": "boolean", "description": "Whether council tax is exempt"},
        {"name": "council_tax_included", "type": "boolean", "description": "Whether council tax is included in rent"},
        {"name": "council_tax_band", "type": "string", "description": "Council tax band classification"},
        {"name": "property_features", "type": "string", "description": "Key features of the property stored as a JSON-style list of strings (e.g. [\"Balcony\", \"Parking\", \"Gym\"]). Each entry represents an amenity or characteristic such as balcony, garden, concierge, parking, or EPC rating."},
        {"name": "listing_update_reason", "type": "string", "description": "Reason for most recent listing update"},
        {"name": "listing_update_date", "type": "datetime", "description": "Date of the most recent listing update, formatted as YYYY-MM-DD (year-month-day)."},
        {"name": "added_on", "type": "datetime", "description": "Date the property was added to the platform, formatted as YYYY-MM-DD (year-month-day)."},
        {"name": "size_sqft_min", "type": "float", "description": "Minimum property size in square feet"},
        {"name": "size_sqft_max", "type": "float", "description": "Maximum property size in square feet"},
        {"name": "latitude", "type": "float", "description": "Latitude of the property"},
        {"name": "longitude", "type": "float", "description": "Longitude of the property"},
        {"name": "nearest_station1_name", "type": "string", "description": "Name of the nearest station"},
        {"name": "nearest_station2_name", "type": "string", "description": "Name of the second nearest station"},
        {"name": "nearest_station3_name", "type": "string", "description": "Name of the third nearest station"},
        {"name": "nearest_station1_distance_km", "type": "float", "description": "Distance to nearest station in km"},
        {"name": "nearest_station2_distance_km", "type": "float", "description": "Distance to second nearest station in km"},
        {"name": "nearest_station3_distance_km", "type": "float", "description": "Distance to third nearest station in km"},
        {"name": "nearest_station1_type", "type": "string", "description": "Type of nearest station (tube, national train, DLR, etc.)"},
        {"name": "nearest_station2_type", "type": "string", "description": "Type of second nearest station"},
        {"name": "nearest_station3_type", "type": "string", "description": "Type of third nearest station"},
        {"name": "borough", "type": "string", "description": "London borough of the property"},
        {"name": "travel_zone", "type": "string", "description": "London Travelcard zone"},
        {"name": "distance_to_center_km", "type": "float", "description": "Distance from property to central London (Charing Cross)"},
        {"name": "noise_level_class", "type": "string", "description": "Noise classification (low, medium, high, no_data)"},
        {"name": "description", "type": "string", "description": "Cleaned free-text property description"},
        {"name": "predicted_price", "type": "float",  "description": "Expected price in GBP predicted by a regression model using property features. Serves as a benchmark to compare against the actual listed price."},
        {"name": "pricing_index", "type": "float", "description": "If less than 1, the property is good value. If greater than 1, it is poor value."},
        {"name": "district","type": "string","description": "Neighbourhood or district within London where the property is located (e.g. Canary Wharf, Shoreditch)."}
    ]
)
# Out:
# Dataset saved successfully to path: new-bot/rental-data-london4
