# %%
import pandas as pd
import pandasai as pai
import os
os.chdir("..")  # move up one level: notebooks → project root
from src.tools import load_pandas_ai_dataframe
import re
import json

# %%
df = pd.read_csv("../data/catboost_districts_added_on.csv")

# %%
df.head()
# Out:
#    Unnamed: 0         id                                              title  \
# 0           0  156331799  3 bedroom apartment for rent in Albany Court, ...
# 1           1  156345644  2 bedroom terraced house for rent in Peal Gard...
# 2           2  153523199  2 bedroom flat for rent in Blackfriars Road, S...
# 3           3  155610035  3 bedroom terraced house for rent in Springfie...
# 4           4  155840024  1 bedroom flat for rent in Upper Street, Angel...
#
#                             display_address postcode_outcode postcode_incode  \
# 0    Albany Court, Spring Grove, London, W4               W4             3BF
# 1   Peal Gardens, Greenford, Middlesex, W13              W13             0BA
# 2  Blackfriars Road, Southwark, London, SE1              SE1             8EW
# 3    Springfield Place, Hornbeam Mews, SW17             SW17             7DJ
# 4           Upper Street, Angel, London, N1               N1             2XQ
#
#    bathrooms  bedrooms property_type  price_gbp  ...     borough travel_zone  \
# 0          3         3     Apartment       3550  ...    Hounslow           3
# 1          1         2      Terraced       2097  ...      Ealing           4
# 2          2         2          Flat       5800  ...   Southwark           1
# 3          3         3      Terraced       3100  ...  Wandsworth           3
# 4          1         1          Flat       2500  ...   Islington           2
#
#    distance_to_center_km spatial_index noise_level_class  zone_hex  \
# 0               6.980505       20867.0              high    Zone 3
# 1               8.765145       14254.0           no_data    Zone 4
# 2               1.146696       24418.0              high    Zone 1
# 3               5.216208         276.0           no_data    Zone 3
# 4               2.327834         654.0       medium-high    Zone 2
#
#                                          description predicted_price  \
# 0  An exceptional 1,080 sq ft, three bedroom, thr...     4248.351722
# 1  Video tour available:  \nA modern 2 Bedrooms h...     1971.855626
# 2  SHORT LET. Set in an exceptional new developme...     5243.815747
# 3  Regent excited to offer this spacious, bright ...     3462.593661
# 4  LONG LET. Situated within highly sought-after ...     2353.953234
#
#   pricing_index            district
# 0      0.835618  Chiswick Riverside
# 1      1.063465           Cleveland
# 2      1.106065        St. George's
# 3      0.895283   Wandsworth Common
# 4      1.062043          St. Mary's
#
# [5 rows x 46 columns]

# %%
df[df["district"] == "Limehouse"]
# Out:
#        Unnamed: 0         id  \
# 322           322  154604651
# 3883         3883  156401795
# 4659         4659  155254349
# 4715         4715  153431048
# 4822         4822  152293322
# 5359         5359  155220746
# 5554         5554  155594372
# 5619         5619  153968972
# 6003         6003  156309074
# 6850         6850  156204470
# 6873         6873  106988477
# 7059         7059  155626544
# 7305         7305  155221598
# 7337         7337  156354350
# 8452         8452  154566170
# 8516         8516  154931312
# 8552         8552  129235667
# 8866         8866  155921792
# 9193         9193  154279514
# 9252         9252  155630426
# 9856         9856  155603141
# 10141       10141  154954064
# 10181       10181   90878284
# 10324       10324  155480054
# 10693       10693  156416540
# 10722       10722  156399428
# 11529       11529  152986664
# 11837       11837  155783546
# 11961       11961  155776937
# 12415       12415  155086649
# 12946       12946  154140827
# 13056       13056  155375138
# 13945       13945  124914638
# 14359       14359  156428822
# 14409       14409  155977679
# 15181       15181  156276122
# 15380       15380   72506420
# 16810       16810  156204509
# 17026       17026  141066470
# 18644       18644  155086622
# 28399          Drake House, 4 Victory Place, London, E14              E14
#
#       postcode_incode  bathrooms  bedrooms property_type  price_gbp  ...  \
# 322               8DG          2         2          Flat       2500  ...
# 3883              7JT          1         1     Apartment       1950  ...
# 4659              8DD          2         2          Flat       2990  ...
# 4715              8AG          1         3          Flat       2800  ...
# 4822              8DE          1         3     Apartment       2750  ...
# 5359              7JX          2         2     Apartment       2650  ...
# 5554              8DD          2         2          Flat       2999  ...
# 5619              7JR          1         1          Flat       1995  ...
# 6003              7JX          2         2          Flat       2600  ...
# 6850              7JT          1         1     Apartment       2300  ...
# 6873              7JT          2         2          Flat       2349  ...
# 7059              8DW          1         1          Flat       1950  ...
# 7305              8HL          1         1          Flat       3000  ...
# 7337              8DN          1         2          Flat       2167  ...
# 8452              8HB          1         1    Flat Share        900  ...
# 8516              8AF          1         4     Apartment       2500  ...
# 8552              8AT          3         3         House       3250  ...
# 8866              8BT          2         2     Apartment       2650  ...
# 9193              7JR          1         1          Flat       1880  ...
# 9252              8DD          2         2          Flat       2999  ...
# 9856              8DG          2         2     Apartment       2899  ...
# 10141             8AP          1         2          Flat       2500  ...
# 10181             8AY          2         2          Flat       2400  ...
# 10324             8AP          1         2     Apartment       2500  ...
# 10693             7JR          2         2     Apartment       2425  ...
# 10722             8FU          1         2     Apartment       3000  ...
# 11529             7JG          1         1          Flat       2100  ...
# 11837             8BH          1         1          Flat       2600  ...
# 11961             8HX          2         2          Flat       2499  ...
# 12415             8BU          2         2          Flat       3500  ...
# 12946             8BY          1         2     Apartment       2300  ...
# 13056             8DP          2         2          Flat       2448  ...
# 13945             8AY          2         2          Flat       2750  ...
# 14359             7JY          2         2     Apartment       2595  ...
# 14409             8BQ          2         2     Apartment       2250  ...
# 15181             7HW          2         2     Apartment       2200  ...
# 15380             8HL          1         1     Apartment       1647  ...
# 16810             8BG          1         1         House       2000  ...
# 17026             8DG          2         2     Penthouse       3500  ...
# 18644             8BU          2         2          Flat       2900  ...
# 19225             8EQ          1         1          Flat       1928  ...
# 20738             8HE          1         1    Flat Share        802  ...
# 21066             7GL          1         2          Flat       2709  ...
# 21501             7JX          2         2     Apartment       2648  ...
# 22191             8HD          1         2          Flat       2000  ...
# 23311             8DP          2         2          Flat       2900  ...
# 24988             7JR          2         2          Flat       2492  ...
# 25293             8BZ          2         2     Apartment       2950  ...
# 25613             7HW          2         2          Flat       2578  ...
# 25776             8DP          1         1          Flat       1750  ...
# 26555             7JB          1         1     Apartment       1950  ...
# 27067             8DW          2         2     Apartment       2500  ...
# 28065             8DW          1         1          Flat       1798  ...
# 28146             7JY          2         2     Apartment       2700  ...
# 28259             8DW          2         2     Apartment       2400  ...
# 28399             8BG          1         2     Apartment       2500  ...
#
#              borough travel_zone  distance_to_center_km spatial_index  \
# 322    Tower Hamlets           2               3.818035       11518.0
# 3883   Tower Hamlets           2               3.834688       26054.0
# 4659   Tower Hamlets           2               3.915185       26887.0
# 4715   Tower Hamlets           2               4.268468       21407.0
# 4822   Tower Hamlets           2               4.183348       21407.0
# 5359   Tower Hamlets           2               3.837902       26054.0
# 5554   Tower Hamlets           2               3.920928       26887.0
# 5619   Tower Hamlets           2               3.885486       24790.0
# 6003   Tower Hamlets           2               3.841929       26054.0
# 6850   Tower Hamlets           2               3.831007       26054.0
# 6873   Tower Hamlets           2               3.860804       26887.0
# 7059   Tower Hamlets           2               3.796925       11518.0
# 7305   Tower Hamlets           2               4.317707       10424.0
# 7337   Tower Hamlets           2               3.833095       26887.0
# 8452   Tower Hamlets           2               4.333887       10424.0
# 8516   Tower Hamlets           2               4.275212       21407.0
# 8552   Tower Hamlets           2               4.259671       21407.0
# 8866   Tower Hamlets           2               4.047762        8776.0
# 9193   Tower Hamlets           2               3.890444       24790.0
# 9252   Tower Hamlets           2               3.916044       26887.0
# 9856   Tower Hamlets           2               3.817901       11518.0
# 10141  Tower Hamlets           2               4.220649       21407.0
# 10181  Tower Hamlets           2               4.140615        4018.0
# 10324  Tower Hamlets           2               4.235004       21407.0
# 10693  Tower Hamlets           2               3.903225       24790.0
# 10722  Tower Hamlets           2               4.352870       10424.0
# 11529  Tower Hamlets           2               4.029245        9098.0
# 11837  Tower Hamlets           2               4.349344       10424.0
# 11961  Tower Hamlets           2               4.328823       10424.0
# 12415  Tower Hamlets           2               4.090412        4018.0
# 12946  Tower Hamlets           2               4.014514        8776.0
# 13056  Tower Hamlets           2               3.781559       11518.0
# 13945  Tower Hamlets           2               4.177391        4018.0
# 14359  Tower Hamlets           2               3.877793       26887.0
# 14409  Tower Hamlets           2               4.013852        9098.0
# 15181  Tower Hamlets           2               4.086169        7153.0
# 15380  Tower Hamlets           2               4.323037       10424.0
# 16810  Tower Hamlets           2               4.025186        9098.0
# 17026  Tower Hamlets           2               3.821936       11518.0
# 18644  Tower Hamlets           2               4.090412        4018.0
# 19225  Tower Hamlets           2               3.907915       26887.0
# 20738  Tower Hamlets           2               4.272212        6524.0
# 21066  Tower Hamlets           2               4.072430        9098.0
# 21501  Tower Hamlets           2               3.836736       26054.0
# 22191  Tower Hamlets           2               4.278861        6524.0
# 23311  Tower Hamlets           2               3.719437        9254.0
# 24988  Tower Hamlets           2               3.873121       24790.0
# 25293  Tower Hamlets           2               3.971025        8776.0
# 25613  Tower Hamlets           2               4.097441        7153.0
# 25776  Tower Hamlets           2               3.774872       11518.0
# 26555  Tower Hamlets           2               3.987965        9098.0
# 27067  Tower Hamlets           2               3.799707       26054.0
# 28065  Tower Hamlets           2               3.801825       11518.0
# 28146  Tower Hamlets           2               3.836587       26054.0
# 28259  Tower Hamlets           2               3.799707       26054.0
# 28399  Tower Hamlets           2               4.012014        9098.0
#
#       noise_level_class  zone_hex  \
# 322                high    Zone 2
# 3883               high    Zone 2
# 4659                low    Zone 2
# 4715             medium    Zone 2
# 4822             medium    Zone 2
# 5359               high    Zone 2
# 5554                low    Zone 2
# 5619        medium-high    Zone 2
# 6003               high    Zone 2
# 6850               high    Zone 2
# 6873                low    Zone 2
# 7059               high    Zone 2
# 7305               high    Zone 2
# 7337                low    Zone 2
# 8452               high    Zone 2
# 8516             medium    Zone 2
# 8552             medium    Zone 2
# 8866            no_data    Zone 2
# 9193        medium-high    Zone 2
# 9252                low    Zone 2
# 9856               high    Zone 2
# 10141            medium    Zone 2
# 10181           no_data    Zone 2
# 10324            medium    Zone 2
# 10693       medium-high    Zone 2
# 10722              high    Zone 2
# 11529       medium-high    Zone 2
# 11837              high    Zone 2
# 11961              high    Zone 2
# 12415           no_data    Zone 2
# 12946           no_data    Zone 2
# 13056              high    Zone 2
# 13945           no_data    Zone 2
# 14359               low    Zone 2
# 14409       medium-high    Zone 2
# 15181       medium-high    Zone 2
# 15380              high    Zone 2
# 16810       medium-high    Zone 2
# 17026              high    Zone 2
# 18644           no_data    Zone 2
# 19225               low    Zone 2
# 20738              high    Zone 2
# 21066       medium-high    Zone 2
# 21501              high    Zone 2
# 22191              high    Zone 2
# 23311              high    Zone 2
# 24988       medium-high    Zone 2
# 25293           no_data    Zone 2
# 25613       medium-high    Zone 2
# 25776              high    Zone 2
# 26555       medium-high    Zone 2
# 27067              high    Zone 2
# 28065              high    Zone 2
# 28146              high    Zone 2
# 28259              high    Zone 2
# 28399       medium-high    Zone 2
#
#                                              description predicted_price  \
# 322    Welcome to your new home at Old Sun Wharf, Lon...     2624.606868
# 3883   On offer is a well-appointed, larger than aver...     1895.313719
# 4659   Property reference number: 23563Please quote t...     2833.371823
# 4715   Property Reference: 2211966.We have a spacious...     2690.489063
# 4822   Open Plan Modern Apartment - Allocated Parking...     3334.359637
# 5359   Fantastic opportunity to rent a 2 bedroom apar...     2619.041185
# 5554   A charming two bedroom apartment on the very d...     2846.044122
# 5619   Property Reference: 2264582.This is a Great 1 ...     1941.038321
# 6003   Property Reference: 2280692.Incredible views o...     2731.747871
# 6850   This beautifully presented furnished one bedro...     1903.234375
# 6873   The remarkably large living room has wooden fl...     2678.061458
# 7059   LONG LET. This fantastic 1 bedroom flat has a ...     1794.588579
# 7305   SHORT LET. Situated close to amenities, this e...     2945.287457
# 7337   Property Reference: 2336107.Situated within th...     2363.480750
# 8452   Property Reference: 2258059.Extra-Large Double...      949.157299
# 8516   Four Bedroom Flat to Rent - Westferry, E14Rent...     3032.011070
# 8552   Nathan Andrews Estates are pleased to present ...     4202.203366
# 8866   A bright and spacious two double bedroom two b...     2783.455132
# 9193   Property Reference: 2274109.Beautiful 1 bedroo...     1925.456164
# 9252   Knight Frank are pleased to offer this 6th flo...     2827.211868
# 9856   This warm two bedroom home spans over three fl...     2770.829334
# 10141  We are pleased to offer this brand two bedroom...     2584.231560
# 10181  Rare to the market, this penthouse floor (6th)...     3021.432348
# 10324  A stunning two-bedroom property with its very ...     2708.200434
# 10693  Hurford Salvi Carr are favoured as sole agents...     2690.064126
# 10722  **Zero Deposit Guarantee Available**Holding De...     2818.197142
# 11529  LONG LET. Located within an impressive develop...     1834.201928
# 11837  A ONE BEDROOM APARTMENT FOR RENT WITH SPACIOUS...     2445.198706
# 11961  A beautifully refurbished top-floor 2-bedroom,...     2935.468179
# 12415  SHORT LET. Spacious 2-bed flat with two double...     3689.464377
# 12946  Hurford Salvi Carr are favoured to market this...     2256.577077
# 13056  Ea2 are pleased to offer for let this generous...     2764.568673
# 13945  A magnificent 2 bedroom 2 bathroom Apartment i...     3113.027566
# 14359  Favoured as the landlord sole agents Hurford S...     2824.875946
# 14409  Hurford Salvi Carr are favoured as sole agents...     2352.211822
# %%
df["property_features"]
# Out:
# 0        ['1080 sq ft' 'Dual Aspect Apartment' 'Three B...
# 1                                                       []
# 2        ['Stylish 2 bedroom flat' 'Large open-plan rec...
# 3        ['Brand New Apartment ' 'Indoor Parking '\n 'O...
# 4        ["Sought after location on Islington's trendy ...
#                                ...
# 28483    ['One double bedroom' 'One bathroom' 'Second f...
# 28484                                                   []
# 28485    ['Two bedroom ground floor apartment'\n 'Priva...
# 28486    ['Newly Refurbished' 'High Ceilings' 'Balcony'...
# 28487                                  ['Communal garden']
# Name: property_features, Length: 28488, dtype: object

# %%
def clean_property_features_to_json(raw):
    if pd.isna(raw) or str(raw).strip() in ["[]", ""]:
        return "[]"

    txt = str(raw).replace("\n", " ").strip()

    # Remove enclosing brackets and quotes artifacts
    txt = re.sub(r'[\[\]]', '', txt)

    # Ensure commas between adjacent quoted parts like: 'A' 'B' → 'A','B'
    txt = re.sub(r"'\s*'", "', '", txt)

    # If ends with an open quote (e.g. 'Garage), close it
    if txt.count("'") % 2 != 0:
        txt += "'"

    # Remove redundant double quotes
    txt = txt.replace('"', '')

    # Split by single quotes and clean
    parts = [p.strip(" ,") for p in txt.split("'") if p.strip() and not p.strip().startswith(",")]

    # Normalize capitalization and remove duplicates
    cleaned = []
    for p in parts:
        if p and p not in cleaned:
            cleaned.append(p.strip().title())

    # Return valid JSON string list
    return json.dumps(cleaned, ensure_ascii=False)

# %%
df["property_features"] = df["property_features"].apply(clean_property_features_to_json)

# %%
s = df["added_on"].astype(str).str.strip()
df["added_on"] = s.str.slice(6, 10) + "-" + s.str.slice(3, 5) + "-" + s.str.slice(0, 2)

# %%
df["added_on"].value_counts()
# Out:
# added_on
# 2025-01-03    1569
# 2025-01-02    1565
# 2024-12-28    1028
# 2024-12-17     679
# 2024-12-10     663
#               ...
# 2023-12-01       1
# 2023-03-28       1
# 2019-10-28       1
# 2023-01-03       1
# 2023-06-30       1
# Name: count, Length: 546, dtype: int64

# %%
df["added_on"].value_counts()

# %%
df["let_available_date"]
# Out:
# 0               Now
# 1        11/01/2025
# 2         Ask agent
# 3               Now
# 4         Ask agent
#             ...
# 28483           Now
# 28484           Now
# 28485           Now
# 28486     Ask agent
# 28487     Ask agent
# Name: let_available_date, Length: 28488, dtype: object

# %%
df["listing_update_date"]
# Out:
# 0        2024-12-30
# 1        2024-12-31
# 2        2024-11-20
# 3        2024-12-12
# 4        2024-12-10
#             ...
# 28483    2024-12-11
# 28484    2024-12-02
# 28485    2024-12-16
# 28486    2024-08-01
# 28487    2024-12-03
# Name: listing_update_date, Length: 28488, dtype: object

# %%
df = df.drop(columns="first_visible_date")

# %%
df = df.drop(columns="let_available_date")

# %%
df = df.drop(columns = "Unnamed: 0")

# %%
df.columns
# Out:
# Index(['id', 'title', 'display_address', 'postcode_outcode', 'postcode_incode',
#        'bathrooms', 'bedrooms', 'property_type', 'price_gbp',
#        'secondary_price_gbp', 'deposit_included_or_not', 'let_type',
#        'furnish_type', 'council_tax_exempt', 'council_tax_included',
#        'council_tax_band', 'property_features', 'listing_update_reason',
#        'listing_update_date', 'added_on', 'size_sqft_min', 'size_sqft_max',
#        'latitude', 'longitude', 'nearest_station1_name',
#        'nearest_station2_name', 'nearest_station3_name',
#        'nearest_station1_distance_km', 'nearest_station2_distance_km',
#        'nearest_station3_distance_km', 'nearest_station1_type',
#        'nearest_station2_type', 'nearest_station3_type', 'borough',
#        'travel_zone', 'distance_to_center_km', 'spatial_index',
#        'noise_level_class', 'zone_hex', 'description', 'predicted_price',
#        'pricing_index', 'district'],
#       dtype='object')

# %%
df.to_csv("../data/catboost_districts_added_on_v2.csv")

# %%
file = pai.read_csv("../data/catboost_districts_added_on_v2.csv")

# %%
df_ai = pai.create(
    path="new-bot/rental-data-london3",
    df=file,
    description="London real estate property listings with pricing, size, location, station proximity, and noise levels",
    columns=[
        {"name": "id", "type": "string", "description": "Unique identifier for each property listing"},
        {"name": "title", "type": "string", "description": "Listing title"},
        {"name": "display_address", "type": "string", "description": "Readable address of the property"},
        {"name": "postcode_outcode", "type": "string", "description": "Outcode part of the UK postcode"},
        {"name": "postcode_incode", "type": "string", "description": "Incode part of the UK postcode"},
        {"name": "bathrooms", "type": "integer", "description": "Number of bathrooms"},
        {"name": "bedrooms", "type": "integer", "description": "Number of bedrooms"},
        {"name": "property_type", "type": "string", "description": "Type of property (flat, apartment, house, etc.)"},
        {"name": "price_gbp", "type": "float", "description": "Listed price in GBP"},
        {"name": "secondary_price_gbp", "type": "float", "description": "Secondary listing price (e.g. weekly rent) in GBP"},
        {"name": "deposit_included_or_not", "type": "string", "description": "Deposit included or (e.g "},
        {"name": "let_type", "type": "string", "description": "Letting type (short term, long term)"},
        {"name": "furnish_type", "type": "string", "description": "Furnishing type (furnished, unfurnished, part furnished)"},
        {"name": "council_tax_exempt", "type": "boolean", "description": "Whether council tax is exempt"},
        {"name": "council_tax_included", "type": "boolean", "description": "Whether council tax is included in rent"},
        {"name": "council_tax_band", "type": "string", "description": "Council tax band classification"},
        {"name": "property_features", "type": "string", "description": "Key features of the property stored as a JSON-style list of strings (e.g. [\"Balcony\", \"Parking\", \"Gym\"]). Each entry represents an amenity or characteristic such as balcony, garden, concierge, parking, or EPC rating."},
        {"name": "listing_update_reason", "type": "string", "description": "Reason for most recent listing update"},
        {"name": "listing_update_date", "type": "datetime", "description": "Date of the most recent listing update, formatted as YYYY-MM-DD (year-month-day)."},
        {"name": "added_on", "type": "datetime", "description": "Date the property was added to the platform, formatted as YYYY-MM-DD (year-month-day)."},
        {"name": "size_sqft_min", "type": "float", "description": "Minimum property size in square feet"},
        {"name": "size_sqft_max", "type": "float", "description": "Maximum property size in square feet"},
        {"name": "latitude", "type": "float", "description": "Latitude of the property"},
        {"name": "longitude", "type": "float", "description": "Longitude of the property"},
        {"name": "nearest_station1_name", "type": "string", "description": "Name of the nearest station"},
        {"name": "nearest_station2_name", "type": "string", "description": "Name of the second nearest station"},
        {"name": "nearest_station3_name", "type": "string", "description": "Name of the third nearest station"},
        {"name": "nearest_station1_distance_km", "type": "float", "description": "Distance to nearest station in km"},
        {"name": "nearest_station2_distance_km", "type": "float", "description": "Distance to second nearest station in km"},
        {"name": "nearest_station3_distance_km", "type": "float", "description": "Distance to third nearest station in km"},
        {"name": "nearest_station1_type", "type": "string", "description": "Type of nearest station (tube, national train, DLR, etc.)"},
        {"name": "nearest_station2_type", "type": "string", "description": "Type of second nearest station"},
        {"name": "nearest_station3_type", "type": "string", "description": "Type of third nearest station"},
        {"name": "borough", "type": "string", "description": "London borough of the property"},
        {"name": "travel_zone", "type": "string", "description": "London Travelcard zone"},
        {"name": "distance_to_center_km", "type": "float", "description": "Distance from property to central London (Charing Cross)"},
        {"name": "noise_level_class", "type": "string", "description": "Noise classification (low, medium, high, no_data)"},
        {"name": "description", "type": "string", "description": "Cleaned free-text property description"},
        {"name": "predicted_price", "type": "float",  "description": "Expected price in GBP predicted by a regression model using property features. Serves as a benchmark to compare against the actual listed price."},
        {"name": "pricing_index", "type": "float", "description": "If less than 1, the property is good value. If greater than 1, it is poor value."},
        {"name": "district","type": "string","description": "Neighbourhood or district within London where the property is located (e.g. Canary Wharf, Shoreditch)."}
    ]
)
# Out:
# Dataset saved successfully to path: new-bot/rental-data-london3

# %%
query = "Show me two bed properties in the Limehouse area under £2500 monthly"

data = load_pandas_ai_dataframe()
result = data.chat(query)
# Out:
# Dataset loaded successfully.

# %%
result.value
# Out:
#            id                                              title  \
# 0   152623520  2 bedroom apartment for rent in Elite House, L...
# 1   156195431  2 bedroom flat for rent in St. Annes Street, L...
# 2   156409349  2 bedroom flat for rent in St. Annes Street, L...
# 3   106988477  2 bedroom flat for rent in Medland House Branc...
# 4   155700353  2 bedroom flat for rent in Clyde Square, Limeh...
# 5   154954064  2 bedroom flat for rent in Three colt Street, ...
# 6   156397121  2 bedroom apartment for rent in Flamborough Wa...
# 7   153513614  2 bedroom maisonette for rent in Burdett Road,...
# 8   155375138  2 bedroom flat for rent in Narrow Street, Lime...
# 9   155822528  2 bedroom apartment for rent in Caspian Apartm...
# 10  155855300  2 bedroom flat for rent in Ben Jonson Road, Li...
# 11  155300630  2 bedroom apartment for rent in Elite House, L...
# 12  155973020  2 bedroom flat for rent in Repton Street, Lime...
# 13  155572088  2 bedroom flat for rent in Old Sailors House, ...
# 14  156175304  2 bedroom flat for rent in Commercial Road, Li...
# 15  155575538  2 bedroom flat for rent in East India Dock Roa...
# 16  154036244  2 bedroom flat for rent in Keymer Place, Limeh...
# 17  156116639  2 bedroom apartment for rent in Ionian Buildin...
#
#                                       display_address postcode_outcode  \
# 0                         Elite House, Limehouse, E14              E14
# 1                         St. Annes Street, Limehouse              E14
# 2                         St. Annes Street, Limehouse              E14
# 3                 Medland House Branch Road Limehouse              E14
# 4   Clyde Square, Limehouse, E14 7TB – 2 Bedrooms ...              E14
# 5                   Three colt Street, Limehouse, E14              E14
# 6                         Flamborough Walk, Limehouse              E14
# 7           Burdett Road, E14, Limehouse, London, E14              E14
# 8                            Narrow Street, Limehouse              E14
# 9   Caspian Apartments, Salton Square, Limehouse, E14              E14
# 10             Ben Jonson Road, Limehouse, London, E1               E1
# 11                        Elite House, Limehouse, E14              E14
# 12              Repton Street, Limehouse, London, E14              E14
# 13          Old Sailors House, Limehouse, London, E14              E14
# 14            Commercial Road, Limehouse, London, E14              E14
# 15  East India Dock Road, Poplar,Limehouse,East Lo...              E14
# 16               Keymer Place, Limehouse, London, E14              E14
# 17  Ionian Building, 45 Narrow Street, Limehouse, E14              E14
#
#    postcode_incode  bathrooms  bedrooms property_type  price_gbp  \
# 0              7PT          2         2     Apartment       2200
# 1              7QB          2         2          Flat       2249
# 2              7QB          2         2          Flat       2249
# 3              7JT          2         2          Flat       2349
# 4              7TB          1         2          Flat       1907
# 5              8AP          1         2          Flat       2500
# 6              7LY          1         2     Apartment       2500
# 7              7AB          1         2    Maisonette       2250
# 8              8DP          2         2          Flat       2448
# 9              7GJ          1         2     Apartment       2000
# 10             4GJ          2         2          Flat       2427
# 11             7PT          2         2     Apartment       2100
# 12             7FR          1         2          Flat       2024
# 13             8HD          1         2          Flat       2000
# 14             7JR          2         2          Flat       2492
# 15             0EG          1         2          Flat       1895
# 16             7RB          2         2          Flat       2200
# 17             8DW          2         2     Apartment       2400
#
#     secondary_price_gbp  ...     nearest_station2_type  \
# 0                   508  ...  ['TFL' 'NATIONAL_TRAIN']
# 1                   519  ...  ['TFL' 'NATIONAL_TRAIN']
# 2                   519  ...  ['TFL' 'NATIONAL_TRAIN']
# 3                   542  ...                   ['TFL']
# 4                   440  ...                   ['TFL']
# 5                   577  ...                   ['TFL']
# 6                   577  ...                   ['TFL']
# 7                   519  ...  ['TFL' 'NATIONAL_TRAIN']
# 8                   565  ...                   ['TFL']
# 9                   462  ...                   ['TFL']
# 10                  560  ...                   ['TFL']
# 11                  485  ...  ['TFL' 'NATIONAL_TRAIN']
# 12                  467  ...                   ['TFL']
# 13                  462  ...                   ['TFL']
# 14                  575  ...                   ['TFL']
# 15                  437  ...                   ['TFL']
# 16                  508  ...  ['TFL' 'NATIONAL_TRAIN']
# 17                  554  ...                   ['TFL']
#
#        nearest_station3_type        borough  travel_zone  \
# 0                    ['TFL']  Tower Hamlets            2
# 1                    ['TFL']  Tower Hamlets            2
# 2                    ['TFL']  Tower Hamlets            2
# 3                    ['TFL']  Tower Hamlets            2
# 4   ['TFL' 'NATIONAL_TRAIN']  Tower Hamlets            2
# 5   ['TFL' 'NATIONAL_TRAIN']  Tower Hamlets            2
# 6                    ['TFL']  Tower Hamlets            2
# 7                    ['TFL']  Tower Hamlets            2
# 8                    ['TFL']  Tower Hamlets            2
# 9                    ['TFL']  Tower Hamlets            2
# 10                   ['TFL']  Tower Hamlets            2
# 11                   ['TFL']  Tower Hamlets            2
# 12                   ['TFL']  Tower Hamlets            2
# 13  ['TFL' 'NATIONAL_TRAIN']  Tower Hamlets            2
# 14                   ['TFL']  Tower Hamlets            2
# 15                   ['TFL']  Tower Hamlets            2
# 16                   ['TFL']  Tower Hamlets            2
# 17                   ['TFL']  Tower Hamlets            2
#
#     distance_to_center_km noise_level_class  \
# 0                4.238487       medium-high
# 1                4.255981       medium-high
# 2                4.255981       medium-high
# 3                3.860804               low
# 4                4.362581              high
# 5                4.220649            medium
# 6                3.858078       medium-high
# 7                4.310272       medium-high
# 8                3.781559              high
# 9                4.042510       medium-high
# 10               4.019454           no_data
# 11               4.238543       medium-high
# 12               4.031603           no_data
# 13               4.278861              high
# 14               3.873121       medium-high
# 15               5.033882              high
# 16               4.254865              high
# 17               3.799707              high
#
#                                           description predicted_price  \
# 0   Available Now | Fully Furnished Located on an ...     2638.858920
# 1   Two double bedroom apartment in Birkdale House...     2513.243082
# 2   Two double bedroom apartment in Birkdale House...     2513.243082
# 3   The remarkably large living room has wooden fl...     2678.061458
# 4   Located in a desirable area with excellent acc...     2255.936616
# 5   We are pleased to offer this brand two bedroom...     2584.231560
# 6   Dawn Sandoval Residential are delighted to off...     2475.079036
# 7   LONG LET. This gorgeous 2 bedroom duplex boast...     2251.779300
# 8   Ea2 are pleased to offer for let this generous...     2764.568673
# 9   Available immediately for rent is this luxurio...     2227.212498
# 10  A two bedroom apartment set within the heart o...     2470.084896
# 11  Available December | Fully FurnishedLocated on...     2580.392438
# 12  LONG LET. A stylish 2 bedroom apartment set on...     2174.994347
# 13  LONG LET. Set within a recently completed hous...     2264.851860
# 14  LONG LET. Spacious two bed flat with pristine ...     2500.294767
# 15  This delightful first-floor flat is offered in...     2006.137497
# 16  Property Reference: 2312004.*Viewings to be he...     2617.882470
# 17  This stunning apartment features spacious two ...     2797.185765
#
#    pricing_index       district
# 0       0.833694       Mile End
# 1       0.894860       Mile End
# 2       0.894860       Mile End
# 3       0.877127      Limehouse
# 4       0.845325       Mile End
# 5       0.967406      Limehouse
# 6       1.010069  St. Dunstan's
# 7       0.999210       Mile End
# 8       0.885491      Limehouse
# 9       0.897983       Mile End
# 10      0.982557  St. Dunstan's
# 11      0.813830       Mile End
# 12      0.930577  St. Dunstan's
# 13      0.883060      Limehouse
# 14      0.996682      Limehouse
# 15      0.944601       Lansbury
# 16      0.840374       Mile End
# 17      0.858005      Limehouse
#
# [18 rows x 41 columns]

# %%
query = "Show me on the map the top ten properties that are good value for money in the Limehouse area"

data = load_pandas_ai_dataframe()
result = data.chat(query)

result.value
# Out:
# Dataset loaded successfully.
#           id                                              title  \
# 0  156276122  2 bedroom apartment for rent in Wharf Lane, Lo...
# 1  129235667  3 bedroom house for rent in Milligan Street, L...
# 2   90878284  2 bedroom flat for rent in Dundee Wharf, 100 T...
# 3  154931312  4 bedroom apartment for rent in Trinidad House...
# 4  152293322  3 bedroom apartment for rent in Barleycorn Way...
# 5   72506420  1 bedroom apartment for rent in Compass Point ...
# 6  155776937     2 bedroom flat for rent in Grenade Street, E14
# 7  156116639  2 bedroom apartment for rent in Ionian Buildin...
# 8  106988477  2 bedroom flat for rent in Medland House Branc...
# 9  152985263  2 bedroom flat for rent in Coral Apartments, L...
#
#                                      display_address postcode_outcode  \
# 0                            Wharf Lane, London, E14              E14
# 1                       Milligan Street, London, E14              E14
# 2   Dundee Wharf, 100 Three Colt Street, London, E14              E14
# 3           Trinidad House, Gill Street, London, E14              E14
# 4          Barleycorn Way, Canary Wharf, London, E14              E14
# 5                 Compass Point Grenande Street E14               E14
# 6                                Grenade Street, E14              E14
# 7  Ionian Building, 45 Narrow Street, Limehouse, E14              E14
# 8                Medland House Branch Road Limehouse              E14
# 9           Coral Apartments, Limehouse, London, E14              E14
#
#   postcode_incode  bathrooms  bedrooms property_type  price_gbp  \
# 0             7HW          2         2     Apartment       2200
# 1             8AT          3         3         House       3250
# 2             8AY          2         2          Flat       2400
# 3             8AF          1         4     Apartment       2500
# 4             8DE          1         3     Apartment       2750
# 5             8HL          1         1     Apartment       1647
# 6             8HX          2         2          Flat       2499
# 7             8DW          2         2     Apartment       2400
# 8             7JT          2         2          Flat       2349
# 9             7GL          1         2          Flat       2709
#
#    secondary_price_gbp  ...     nearest_station2_type  \
# 0                  508  ...  ['TFL' 'NATIONAL_TRAIN']
# 1                  750  ...                   ['TFL']
# 2                  554  ...                   ['TFL']
# 3                  577  ...                   ['TFL']
# 4                  635  ...  ['TFL' 'NATIONAL_TRAIN']
# 5                  380  ...                   ['TFL']
# 6                  577  ...                   ['TFL']
# 7                  554  ...                   ['TFL']
# 8                  542  ...                   ['TFL']
# 9                  625  ...                   ['TFL']
#
#       nearest_station3_type        borough  travel_zone  \
# 0                   ['TFL']  Tower Hamlets            2
# 1                   ['TFL']  Tower Hamlets            2
# 2  ['TFL' 'NATIONAL_TRAIN']  Tower Hamlets            2
# 3  ['TFL' 'NATIONAL_TRAIN']  Tower Hamlets            2
# 4                   ['TFL']  Tower Hamlets            2
# 5  ['TFL' 'NATIONAL_TRAIN']  Tower Hamlets            2
# 6  ['TFL' 'NATIONAL_TRAIN']  Tower Hamlets            2
# 7                   ['TFL']  Tower Hamlets            2
# 8                   ['TFL']  Tower Hamlets            2
# 9                   ['TFL']  Tower Hamlets            2
#
#    distance_to_center_km noise_level_class  \
# 0               4.086169       medium-high
# 1               4.259671            medium
# 2               4.140615           no_data
# 3               4.275212            medium
# 4               4.183348            medium
# 5               4.323037              high
# 6               4.328823              high
# 7               3.799707              high
# 8               3.860804               low
# 9               4.072430       medium-high
#
#                                          description predicted_price  \
# 0  Presenting a 5th floor 793 sq. ft. apartment, ...     2908.926996
# 1  Nathan Andrews Estates are pleased to present ...     4202.203366
# 2  Rare to the market, this penthouse floor (6th)...     3021.432348
# 3  Four Bedroom Flat to Rent - Westferry, E14Rent...     3032.011070
# 4  Open Plan Modern Apartment - Allocated Parking...     3334.359637
# 5  Rubicon have pleasure in offering this excelle...     1995.300440
# 6  A beautifully refurbished top-floor 2-bedroom,...     2935.468179
# 7  This stunning apartment features spacious two ...     2797.185765
# 8  The remarkably large living room has wooden fl...     2678.061458
# 9  SHORT LET. Set within a secure development, th...     3082.601405
#
#   pricing_index   district
# 0      0.756293  Limehouse
# 1      0.773404  Limehouse
# 2      0.794325  Limehouse
# 3      0.824535  Limehouse
# 4      0.824746  Limehouse
# 5      0.825440  Limehouse
# 6      0.851312  Limehouse
# 7      0.858005  Limehouse
# 8      0.877127  Limehouse
# 9      0.878803  Limehouse
#
# [10 rows x 41 columns]

# %%
query = "how is london property market this year?"

data = load_pandas_ai_dataframe()
result = data.chat(query)

result.value
# Out:
# Dataset loaded successfully.
#     average_price   property_type
# 0     4315.393120        Detached
# 1     2814.716216      Maisonette
# 2     3144.751553  End of Terrace
# 3      959.678766     House Share
# 4     3045.958911            Flat
# 5     2485.720909           other
# 6     3360.146064       Apartment
# 7     3854.219612           House
# 8     5621.311404       Penthouse
# 9     3460.028369        Terraced
# 10    1121.451220      Flat Share
# 11    3449.649543   Semi-Detached
